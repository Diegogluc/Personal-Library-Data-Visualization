# %%
from google.oauth2.service_account import Credentials
import gspread
import pandas as pd
import requests
import json
import unicodedata
from difflib import SequenceMatcher

# %%
def similarity_ratio(str1, str2):
    """Calculates the similarity ratio between two strings."""
    return SequenceMatcher(None, str1, str2).ratio()

def find_book_google_books_advanced(title, author, title_similarity_threshold=0.8, author_similarity_threshold=0.8):
    """
    Searches the Google Books API for a book using advanced matching logic.

    Args:
        title (str): The title of the book.
        author (str): The author of the book.
        title_similarity_threshold (float): Minimum similarity ratio for title match (0.0 to 1.0).
        author_similarity_threshold (float): Minimum similarity ratio for author match (0.0 to 1.0).

    Returns:
        dict or None: A dictionary containing information about the best matching book,
                     or None if no sufficiently similar book is found or an error occurs.
    """
    base_url = "https://www.googleapis.com/books/v1/volumes"
    params = {"q": f"{title} inauthor:{author}"}
    best_match = None
    highest_similarity = 0.0

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        items = data.get("items", [])

        if items:
            for item in items:
                info = item.get("volumeInfo", {})
                title_api = info.get("title", "").lower()
                authors_api = [a.lower() for a in info.get("authors", [])]

                title_similarity = similarity_ratio(title.lower(), title_api)
                author_similarity = 0.0
                if authors_api:
                    max_author_similarity = 0.0
                    for author_from_api in authors_api:
                        current_similarity = similarity_ratio(author.lower(), author_from_api)
                        max_author_similarity = max(max_author_similarity, current_similarity)
                    author_similarity = max_author_similarity
                elif not author:  # If no author is provided in the search, consider it a match
                    author_similarity = 1.0

                combined_similarity = (title_similarity + author_similarity) / 2.0

                if title_similarity >= title_similarity_threshold and author_similarity >= author_similarity_threshold:
                    if combined_similarity > highest_similarity:
                        highest_similarity = combined_similarity
                        best_match = info

        # If no good match with both title and author, try searching by title only with a lower threshold
        if not best_match:
            params_title_only = {"q": title}
            response_title_only = requests.get(base_url, params=params_title_only)
            response_title_only.raise_for_status()
            data_title_only = response_title_only.json()
            items_title_only = data_title_only.get("items", [])

            if items_title_only:
                for item in items_title_only:
                    info = item.get("volumeInfo", {})
                    title_api = info.get("title", "").lower()
                    title_similarity = similarity_ratio(title.lower(), title_api)
                    if title_similarity >= title_similarity_threshold - 0.1: # Lower threshold for title-only search
                        if title_similarity > highest_similarity:
                            highest_similarity = title_similarity
                            best_match = info

        return best_match

    except requests.exceptions.RequestException as e:
        print(f"Error during API request: {e}")
        return None
    
def add_columns(sheet, num_columns_to_add):
    """Adds a specified number of columns to the Google Sheet."""
    try:
        properties = sheet.fetch_sheet_metadata()['sheets'][0]['properties']
        current_column_count = properties['gridProperties']['columnCount']
        new_column_count = current_column_count + num_columns_to_add

        body = {
            "requests": [
                {
                    "updateSheetProperties": {
                        "properties": {
                            "gridProperties": {
                                "columnCount": new_column_count
                            }
                        },
                        "fields": "gridProperties.columnCount"
                    }
                }
            ]
        }
        sheet.batch_update(body)

    except gspread.exceptions.APIError as e:
        print(f"Error adding columns: {e}")

def insert_info_in_sheet(sheet, info_to_add):
    """
    Inserts information into the Google Sheets based on the provided parameters.

    Args:
        sheet (gspread.models.Spreadsheet): The Google Sheets object.
        info_to_add (str): The field name (e.g. 'Category') to be fetched and added to the sheet.

    Returns:
        None
    """
    sheet1 = sheet.sheet1
    values_list = sheet1.get_all_values()

    info_searched = info_to_add.lower()
    header_row = values_list[0]
    num_cols = len(header_row)

    # Get column indices for title and author
    title_column_index = header_row.index("Book_Title") if "Book_Title" in header_row else 0
    author_column_index = header_row.index("Author") if "Author" in header_row else 1

    # Add new column if info_to_add is not in header
    if info_searched.capitalize() not in header_row:
        sheet1.add_cols(1)
        num_cols += 1
        sheet1.update_cell(1, num_cols, info_searched.capitalize())
        info_column_index = num_cols - 1
    else:
        info_column_index = header_row.index(info_searched.capitalize())

    # Get rows where info_to_add is empty or missing
    empty_rows = [
        i + 2 for i, row in enumerate(values_list[1:])  # skip header
        if len(row) <= info_column_index or not row[info_column_index]
    ]

    try:
        for row_index in empty_rows:
            if row_index - 1 < len(values_list):
                book = values_list[row_index - 1]
                if len(book) <= max(title_column_index, author_column_index):
                    continue  # skip incomplete rows

                title_name = book[title_column_index].strip()
                author_name = book[author_column_index].strip()

                book_api_info = find_book_google_books_advanced(title_name, author_name)

                if book_api_info and info_to_add in book_api_info:
                    info_value = book_api_info[info_to_add]
                    if not info_value:
                        info_value = "Unknown"
                else:
                    info_value = "Unknown"

                print(f"Updating row {row_index}: '{title_name}' → {info_searched.capitalize()} = {info_value}")
                # Convert list or other non-string types to string
                if isinstance(info_value, list):
                    info_value = ", ".join(info_value)
                elif not isinstance(info_value, str):
                    info_value = str(info_value)

                sheet1.update_cell(row_index, info_column_index + 1, info_value)


    except gspread.exceptions.APIError as e:
        print(f"Google Sheets API Error: {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

def get_book_keys(sheet):
    """
    Efficiently retrieves the set of keys returned by the Google Books API for each unique book.
    Avoids redundant API calls and skips header row properly.

    Args:
        sheet (gspread.models.Spreadsheet): The Google Sheets object.

    Returns:
        list: A list of unique sets of keys from the book API results.
    """
    values_list = sheet.sheet1.get_all_values()
    header_row = values_list[0]

    try:
        title_col = header_row.index("Book_Title")
    except ValueError:
        print("Warning: 'Book_Title' column not found. Assuming index 0.")
        title_col = 0

    try:
        author_col = header_row.index("Author")
    except ValueError:
        print("Warning: 'Author' column not found. Assuming index 1.")
        author_col = 1

    keys = []
    seen_titles = set()

    for row in values_list[1:]:  # skip header
        if len(row) <= max(title_col, author_col):
            continue  # skip malformed rows

        title = row[title_col].strip()
        author = row[author_col].strip()

        key = (title.lower(), author.lower())
        if key in seen_titles:
            continue  # skip duplicates

        seen_titles.add(key)

        book_info = find_book_google_books_advanced(title, author)
        if book_info:
            api_keys_set = frozenset(book_info.keys())
            if api_keys_set not in keys:
                keys.append(api_keys_set)

    return keys

def save_sheet_as_sql(sheet, table_name="books", output_file="sheet_export.sql"):
    """
    Saves the contents of a Google Sheet as SQL INSERT statements in a .sql file.

    Args:
        sheet (gspread.models.Spreadsheet): Authenticated Google Sheet object.
        table_name (str): Name of the SQL table.
        output_file (str): Path to the output .sql file.
    """
    sheet1 = sheet.sheet1
    values = sheet1.get_all_values()

    headers = values[0]  # column names
    rows = values[1:]    # data rows

    with open(output_file, "w", encoding="utf-8") as f:
        for row in rows:
            # Pad row to match header length
            row += [""] * (len(headers) - len(row))

            # Sanitize and format values
            sanitized_values = []
            for cell in row:
                # Handle strings and escape single quotes
                if isinstance(cell, str):
                    cell = cell.replace("'", "''")
                    sanitized_values.append(f"'{cell}'")
                else:
                    sanitized_values.append("NULL" if cell == "" else str(cell))

            insert_stmt = f"INSERT INTO {table_name} ({', '.join(headers)}) VALUES ({', '.join(sanitized_values)});"
            f.write(insert_stmt + "\n")

    print(f"SQL export complete: {output_file}")

def save_sheet_as_json(sheet, output_filename):
    """
    Save the contents of a Google Sheet as a JSON file.
    Args:
        sheet (gspread.models.Spreadsheet): Authenticated Google Sheet object.
        output_filename (str): Path to the output JSON file (without extension).  
    """

    try:
        # Get all values from the worksheet as a list of lists
        data = sheet.sheet1.get_all_values()

        # Convert the list of lists into a list of dictionaries (assuming the first row is the header)
        if data:
            headers = data[0]
            json_data = [dict(zip(headers, row)) for row in data[1:]]
        else:
            json_data = []

        # Save the JSON data to a file
        with open(output_filename, 'w', encoding='utf-8') as f:
            json.dump(json_data, f, indent=4, ensure_ascii=False)

        print(f"Sheet '{sheet}' saved as '{output_filename}'")
    
    except Exception as e:
        print(f"Error saving sheet as JSON: {e}")

def set_first_row_filter(sheet):
    """
    Sets a filter on the first row of the first worksheet in the given Google Sheet.

    Args:
        sheet (gspread.models.Spreadsheet): The Google Sheets object.

    Returns:
        None
    """
    sheet1 = sheet.sheet1
    values_list = sheet1.get_all_values()
    if not values_list:
        print("The sheet is empty, cannot set a filter.")
        return

    num_cols = len(values_list[0])
    if num_cols == 0:
        print("The first row is empty, cannot set a filter.")
        return

    try:
        end_column_letter = chr(ord('A') + num_cols - 1)
        filter_range = f"{sheet1.title}!A1:{end_column_letter}1"
        sheet.add_filter(filter_range)
        print(f"Filter applied to the first row of '{sheet1.title}'.")
    except gspread.exceptions.APIError as e:
        print(f"Error applying filter: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]
creds = Credentials.from_service_account_file("credentials.json", scopes=SCOPES)
gc = gspread.authorize(creds)

# %%
sheet_id = "19JV7gS3Iy_MTOluozSech3iFmkxRF11oCVYLhp1ziN0"
sheet = gc.open_by_key(sheet_id)

values_list = sheet.sheet1.get_all_values()
records = sheet.sheet1.get_all_records()  # fast and efficient

# %%
pd.DataFrame(values_list, columns=values_list[0]).drop(index=0)
# Out:
#                                    Book_Title                   Author  \
# 1                                   O Cortiço          Aluísio Azevedo
# 2            Harry Potter e a Pedra Filosofal            J. K. Rowling
# 3             Harry Potter e a Câmara Secreta            J. K. Rowling
# 4             Harry Potter e o Cálice de Fogo            J. K. Rowling
# 5     Harry Potter e o Prizioneiro de Azkaban            J. K. Rowling
# ..                                        ...                      ...
# 106                          O Senhor do Arco            Conn Iggulden
# 107             Quadribol através dos séculos            J. K. Rowling
# 108    Sherlock Holme - O Cão de Baskervilles  Sr. Arthur Connan Doyle
# 109        Sherlock Holmes - O Vale do Terror  Sr. Arthur Connan Doyle
# 110  A morte e a morte de Quincas Berro Dágua              Jorge Amado
#
#          Publisher Number_of_pages             Translator Year_bought  \
# 1         Sextante             110                      -        1976
# 2            Rocco             263              Lia Wyler        2000
# 3            Rocco             287              Lia Wyler        2001
# 4            Rocco             583              Lia Wyler        2002
# 5            Rocco             348              Lia Wyler        2002
# ..             ...             ...                    ...         ...
# 106         Record             418           Alves Calado           -
# 107          Rocco              63              Lia Wyler           -
# 108  Melhoramentos             336  Antonio Carlos Vilela           -
# 109  Melhoramentos             326  Antonio Carlos Vilela           -
# 110         Record             103                      -          -
#
#        Status         Owner
# 1    Não Lido         Diego
# 2        Lido          Hugo
# 3        Lido  Hugo e Diego
# 4        Lido  Hugo e Diego
# 5        Lido         Diego
# ..        ...           ...
# 106  Não Lido         Diego
# 107      Lido         Diego
# 108      Lido         Diego
# 109      Lido         Diego
# 110      Lido          Hugo
#
# [110 rows x 8 columns]

# %%
library = pd.DataFrame(values_list, columns=values_list[0]).drop(index=0)
library["Status"].unique()  # Check unique values in the Status column
# Out:
# array(['Não Lido', 'Lido'], dtype=object)

# %%
infos_to_search = get_book_keys(sheet)
print(f"Infos to search: {infos_to_search}")
# Out:
# Infos to search: [frozenset({'categories', 'description', 'allowAnonLogging', 'panelizationSummary', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'categories', 'title', 'publishedDate', 'description', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'panelizationSummary', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'categories', 'description', 'ratingsCount', 'allowAnonLogging', 'panelizationSummary', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'averageRating', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'categories', 'title', 'publishedDate', 'description', 'pageCount', 'ratingsCount', 'contentVersion', 'previewLink', 'maturityRating', 'infoLink', 'printType', 'language', 'readingModes', 'authors', 'averageRating', 'allowAnonLogging', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'title', 'publishedDate', 'description', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'imageLinks', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'publisher', 'panelizationSummary', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'title', 'publishedDate', 'description', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'description', 'ratingsCount', 'allowAnonLogging', 'panelizationSummary', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'averageRating', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'categories', 'ratingsCount', 'allowAnonLogging', 'panelizationSummary', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'averageRating', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'categories', 'title', 'publishedDate', 'description', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'imageLinks', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'panelizationSummary', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'categories', 'title', 'publishedDate', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'imageLinks', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'publisher', 'panelizationSummary', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'title', 'publishedDate', 'pageCount', 'contentVersion', 'infoLink', 'previewLink', 'maturityRating', 'imageLinks', 'printType', 'language', 'readingModes', 'authors', 'allowAnonLogging', 'panelizationSummary', 'canonicalVolumeLink', 'industryIdentifiers'}), frozenset({'categories', 'description', 'ratingsCount', 'allowAnonLogging', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'averageRating', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'subtitle', 'categories', 'description', 'allowAnonLogging', 'panelizationSummary', 'pageCount', 'printType', 'readingModes', 'canonicalVolumeLink', 'industryIdentifiers', 'publishedDate', 'contentVersion', 'infoLink', 'maturityRating', 'authors', 'publisher', 'title', 'imageLinks', 'language', 'previewLink'}), frozenset({'title', 'publi ...

# %%
info = "categories"

insert_info_in_sheet(sheet, info)
# Out:
# Updating row 2: 'O Cortiço' → Categories = ['Young Adult Fiction']
# Updating row 3: 'Harry Potter e a Pedra Filosofal' → Categories = ['Fiction']
# Updating row 4: 'Harry Potter e a Câmara Secreta' → Categories = ['Juvenile Fiction']
# Updating row 5: 'Harry Potter e o Cálice de Fogo' → Categories = ['Adventure stories']
# Updating row 6: 'Harry Potter e o Prizioneiro de Azkaban' → Categories = ['Adventure stories']
# Updating row 7: 'Meu Pé de Laranja Lima' → Categories = Unknown
# Updating row 8: 'Amor não tem cor' → Categories = Unknown
# Updating row 9: 'Auto da Compadecida' → Categories = ['Drama']
# Updating row 10: 'Memórias póstumas de Brás Cubas' → Categories = ['Fiction']
# Updating row 11: 'O Fantasma de Canterville - Uma novela e três contos' → Categories = ['Fiction']
# Updating row 12: 'O Grande Mentecapto' → Categories = ['Fiction']
# Updating row 13: 'Ponciá Vicêncio' → Categories = ['Fiction']
# Updating row 14: 'Senhora' → Categories = Unknown
# Updating row 15: '26 Poetas Hoje' → Categories = ['Poetry']
# Updating row 16: 'Maira' → Categories = ['Fiction']
# Updating row 17: 'O recado do Morro' → Categories = ['Fiction']
# Updating row 18: 'Prosas seguidas de odes mínimas' → Categories = ['Poetry']
# Updating row 19: 'A vida, o universo e tudo mais' → Categories = ['Fiction']
# Updating row 20: 'Até mais, e obrigado pelos peixes!' → Categories = ['Fiction']
# Updating row 21: 'O Guia do Mochilero das Galáxias' → Categories = ['Fiction']
# Updating row 22: 'O Restaurante no fim do Universo' → Categories = Unknown
# Updating row 23: 'Antes do Baile Verde' → Categories = ['Fiction']
# Updating row 24: 'Bastardos Inglórios' → Categories = Unknown
# Updating row 25: 'Cobra Norato' → Categories = ['Fiction']
# Updating row 26: 'Cônica da casa assassinada' → Categories = ['Literary Criticism']
# Updating row 27: 'Laços de Família' → Categories = ['Fiction']
# Updating row 28: 'Os da minha rua' → Categories = ['Fiction']
# Updating row 29: 'Sermões Escolhidos' → Categories = ['Fiction']
# Updating row 30: 'Uma vida em Segredo' → Categories = Unknown
# Updating row 31: 'A arte da Guerra' → Categories = ['Literary Collections']
# Updating row 32: 'Através do Espelo e o que Alice encontrou por lá' → Categories = ['Antiques & Collectibles']
# Updating row 33: 'Aventuras de Alice no país das maravilhas' → Categories = ['Fiction']
# Updating row 34: 'O Iluminado' → Categories = ['Fiction']
# Updating row 35: 'A Fúria dos Reis' → Categories = ['Fiction']
# Updating row 36: 'A Guerra dos Tronos' → Categories = ['Fiction']
# Updating row 37: 'A Tormenta das Espadas' → Categories = ['Fiction']
# Updating row 38: 'O Festim dos Corvos' → Categories = ['Fiction']
# Updating row 39: 'A Dance with Dragons' → Categories = ['Fiction']
# Updating row 40: 'A menina que roubava Livros' → Categories = ['Fiction']
# Updating row 41: 'A Dança dos Dragões' → Categories = ['Fiction']
# Updating row 42: 'Contos Inacabados' → Categories = ['Fiction']
# Updating row 43: 'Deuses Americanos' → Categories = ['Bodyguards']
# Updating row 44: 'Mitologia Nórdica' → Categories = ['Fiction']
# Updating row 45: 'Morte no Nilo' → Categories = ['Fiction']
# Updating row 46: 'O Assassinato No Expresso Oriente' → Categories = ['Fiction']
# Updating row 47: 'O Caso de Charles Dexter Ward' → Categories = ['Fiction']
# Updating row 48: 'O oceano no fim do caminho' → Categories = ['Young Adult Fiction']
# Updating row 49: 'Os meninos da Rua Paulo' → Categories = ['Young Adult Fiction']
# Updating row 50: 'Um corpo na Biblioteca' → Categories = ['Fiction']
# Updating row 51: 'A História da Mitologia para quem tem pressa' → Categories = ['History']
# Updating row 52: 'A Náusea' → Categories = Unknown
# Updating row 53: 'Astrofísica para Apressados' → Categories = ['Science']
# Updating row 54: 'Buracos Negros' → Categories = ['Science']
# Updating row 55: 'Cosmos' → Categories = ['Science']
# Updating row 56: 'O gigante enterrado' → Categories = ['Fiction']
# Updating row 57: 'O inverno dos escritores mortos' → Categories = Unknown
# Updating row 58: 'Tropas Estrelares' → Categories = ['Fiction']
# Updating row 59: 'Um Estranho numa terra estranha' → Categories = ['Fiction']
# Updating row 60: 'Uma Breve história do tempo' → Categories = ['Science']
# Updating row 61: 'A Trilogia Dupin' → Categories = ['Fiction']
# Updating row 62: 'Harry Potter e a Ordem da Fênix' → Categories = ['Hogwarts School of Witchcraft and Wizardry (Imaginary organization)']
# Updating row 63: 'Harry Potter e as Relíquias da Morte' → Categories = Unknown
# Updating row 64: 'Harry Potter e o Enigma do Príncipe' → Categories = ['Juvenile Fiction']
# Updating row 65: 'Não me abandone jamais' → Categories = ['Fiction']
# Updating row 66: 'Neuromancer' → Categories = ['Fiction']
# Updating row 67: 'O Livro do Cemitério' → Categories = ['Young Adult Fiction']
# Updating row 68: 'O universo numa casca de noz' → Categories = ['Science']
# Updating row 69: 'As mais belas lendas da Idade Média' → Categories = Unknown
# Updating row 70: 'Barba ensopada de sangue' → Categories = ['Fiction']
# Updating row 71: 'Coraline' → Categories = ['Young Adult Fiction']
# Updating row 72: 'Flores para Algernon' → Categories = ['Fiction']
# Updating row 73: 'Jackob, o mentiroso' → Categories = Unknown
# Updating row 74: 'Labirinto do Fauno' → Categories = ['Fiction']
# Updating row 75: 'Metrópolis' → Categories = ['Fiction']
# Updating row 76: 'O Demônio na Cidade Branca' → Categories = ['History']
# Updating row 77: 'O Perfume' → Categories = ['Fiction']
# Updating row 78: 'Os Filhos de Húrin' → Categories = ['Fiction']
# Updating row 79: 'Um amor incômodo' → Categories = ['Fiction']
# Updating row 80: 'Arsène Lupin contra Herlock Sholmes' → Categories = ['Fiction']
# Updating row 81: 'Arsène Lupin o ladrão de casaca' → Categories = ['Fiction']
# Updating row 82: 'Duna' → Categories = ['Fiction']
# Updating row 83: 'Encontro com Rama' → Categories = ['Fiction']
# Updating row 84: 'Eu receberia as piores noticias dos seus lindos lábios' → Categories = ['Fiction']
# Updating row 85: 'Eu robo' → Categories = ['Fiction']
# Updating row 86: 'Fahrenheit 451' → Categories = ['Fiction']
# Updating row 87: 'Messias de Duna' → Categories = ['Fiction']
# Updating row 88: 'O chamado de Cthulhu e outros contos' → Categories = ['Fiction']
# Updating row 89: 'Uma mulher no escuro' → Categories = Unknown
# Updating row 90: 'Admirável mundo novo' → Categories = ['Fiction']
# Updating row 91: 'Deuses Exteriores e Deuses Anciãos' → Categories = Unknown
# Updating row 92: 'Livro Fenomenal' → Categories = Unknown
# Updating row 93: 'O Homem invisível' → Categories = ['Fiction']
# Updating row 94: 'Os Grandes Antigos' → Categories = Unknown
# Updating row 95: 'Primeiro como tragédia, depois como farsa' → Categories = ['Philosophy']
# Updating row 96: 'Serviçais e raças independentes' → Categories = Unknown
# Updating row 97: 'Murder at Holly House' → Categories = ['Fiction']
# Updating row 98: 'As esganadas' → Categories = ['Fiction']
# Updating row 99: 'Crônicas 1' → Categories = Unknown
# Updating row 100: 'Depois daquela viagem' → Categories = ['Young Adult Fiction']
# Updating row 101: 'Extremamente alto & Incrivelmente perto' → Categories = Unknown
# Updating row 102: 'Melhores Poemas Mario Quintana' → Categories = ['Poetry']
# Updating row 103: 'Nietzsche para estressados' → Categories = ['Self-Help']
# Updating row 104: 'O lobo das planices' → Categories = Unknown
# Updating row 105: 'O retrato de Dorian Gray' → Categories = ['Fiction']
# Updating row 106: 'O Senhor da Chuva' → Categories = ['Fiction']
# Updating row 107: 'O Senhor do Arco' → Categories = ['Fiction']
# Updating row 108: 'Quadribol através dos séculos' → Categories = ['Games & Activities']
# Updating row 109: 'Sherlock Holme - O Cão de Baskervilles' → Categories = ['Fiction']
# Updating row 110: 'Sherlock Holmes - O Vale do Terror' → Categories = ['Fiction']
# Updating row 111: 'A morte e a morte de Quincas Berro Dágua' → Categories = ['Fiction']

# %%
info = "language"

insert_info_in_sheet(sheet, info)
# Out:
# Updating row 2: 'O Cortiço' → Language = pt-BR
# Updating row 3: 'Harry Potter e a Pedra Filosofal' → Language = pt-BR
# Updating row 4: 'Harry Potter e a Câmara Secreta' → Language = pt-BR
# Updating row 5: 'Harry Potter e o Cálice de Fogo' → Language = pt-BR
# Updating row 6: 'Harry Potter e o Prizioneiro de Azkaban' → Language = pt-BR
# Updating row 7: 'Meu Pé de Laranja Lima' → Language = pt-BR
# Updating row 8: 'Amor não tem cor' → Language = pt-BR
# Updating row 9: 'Auto da Compadecida' → Language = pt-BR
# Updating row 10: 'Memórias póstumas de Brás Cubas' → Language = pt
# Updating row 11: 'O Fantasma de Canterville - Uma novela e três contos' → Language = pt-BR
# Updating row 12: 'O Grande Mentecapto' → Language = pt-BR
# Updating row 13: 'Ponciá Vicêncio' → Language = pt-BR
# Updating row 14: 'Senhora' → Language = pt-BR
# Updating row 15: '26 Poetas Hoje' → Language = pt-BR
# Updating row 16: 'Maira' → Language = en
# Updating row 17: 'O recado do Morro' → Language = pt-BR
# Updating row 18: 'Prosas seguidas de odes mínimas' → Language = pt-BR
# Updating row 19: 'A vida, o universo e tudo mais' → Language = pt-BR
# Updating row 20: 'Até mais, e obrigado pelos peixes!' → Language = pt-BR
# Updating row 21: 'O Guia do Mochilero das Galáxias' → Language = pt-BR
# Updating row 22: 'O Restaurante no fim do Universo' → Language = pt-BR
# Updating row 23: 'Antes do Baile Verde' → Language = pt-BR
# Updating row 24: 'Bastardos Inglórios' → Language = Unknown
# Updating row 25: 'Cobra Norato' → Language = pt-BR
# Updating row 26: 'Cônica da casa assassinada' → Language = pt-BR
# Updating row 27: 'Laços de Família' → Language = pt-BR
# Updating row 28: 'Os da minha rua' → Language = pt-BR
# Updating row 29: 'Sermões Escolhidos' → Language = pt-BR
# Updating row 30: 'Uma vida em Segredo' → Language = pt-BR
# Updating row 31: 'A arte da Guerra' → Language = pt-BR
# Updating row 32: 'Através do Espelo e o que Alice encontrou por lá' → Language = pt-BR
# Updating row 33: 'Aventuras de Alice no país das maravilhas' → Language = pt-BR
# Updating row 34: 'O Iluminado' → Language = pt-BR
# Updating row 35: 'A Fúria dos Reis' → Language = pt-BR
# Updating row 36: 'A Guerra dos Tronos' → Language = pt-BR
# Updating row 37: 'A Tormenta das Espadas' → Language = pt-BR
# Updating row 38: 'O Festim dos Corvos' → Language = pt-BR
# Updating row 39: 'A Dance with Dragons' → Language = en
# Updating row 40: 'A menina que roubava Livros' → Language = pt-BR
# Updating row 41: 'A Dança dos Dragões' → Language = pt-BR
# Updating row 42: 'Contos Inacabados' → Language = pt-BR
# Updating row 43: 'Deuses Americanos' → Language = pt-BR
# Updating row 44: 'Mitologia Nórdica' → Language = pt-BR
# Updating row 45: 'Morte no Nilo' → Language = pt-BR
# Updating row 46: 'O Assassinato No Expresso Oriente' → Language = pt-BR
# Updating row 47: 'O Caso de Charles Dexter Ward' → Language = pt-BR
# Updating row 48: 'O oceano no fim do caminho' → Language = pt-BR
# Updating row 49: 'Os meninos da Rua Paulo' → Language = pt-BR
# Updating row 50: 'Um corpo na Biblioteca' → Language = pt-BR
# Updating row 51: 'A História da Mitologia para quem tem pressa' → Language = pt-BR
# Updating row 52: 'A Náusea' → Language = pt-BR
# Updating row 53: 'Astrofísica para Apressados' → Language = pt
# Updating row 54: 'Buracos Negros' → Language = pt-BR
# Updating row 55: 'Cosmos' → Language = en
# Updating row 56: 'O gigante enterrado' → Language = pt-BR
# Updating row 57: 'O inverno dos escritores mortos' → Language = Unknown
# Updating row 58: 'Tropas Estrelares' → Language = pt-BR
# Updating row 59: 'Um Estranho numa terra estranha' → Language = pt-BR
# Updating row 60: 'Uma Breve história do tempo' → Language = pt-BR
# Updating row 61: 'A Trilogia Dupin' → Language = pt-BR
# Updating row 62: 'Harry Potter e a Ordem da Fênix' → Language = pt-BR
# Updating row 63: 'Harry Potter e as Relíquias da Morte' → Language = gl
# Updating row 64: 'Harry Potter e o Enigma do Príncipe' → Language = pt-BR
# Updating row 65: 'Não me abandone jamais' → Language = pt-BR
# Updating row 66: 'Neuromancer' → Language = pt-BR
# Updating row 67: 'O Livro do Cemitério' → Language = pt-BR
# Updating row 68: 'O universo numa casca de noz' → Language = pt-BR
# Updating row 69: 'As mais belas lendas da Idade Média' → Language = pt-BR
# Updating row 70: 'Barba ensopada de sangue' → Language = pt-BR
# Updating row 71: 'Coraline' → Language = pt-BR
# Updating row 72: 'Flores para Algernon' → Language = pt-BR
# Updating row 73: 'Jackob, o mentiroso' → Language = pt-BR
# Updating row 74: 'Labirinto do Fauno' → Language = pt
# Updating row 75: 'Metrópolis' → Language = en
# Updating row 76: 'O Demônio na Cidade Branca' → Language = pt-BR
# Updating row 77: 'O Perfume' → Language = pt-BR
# Updating row 78: 'Os Filhos de Húrin' → Language = pt-BR
# Updating row 79: 'Um amor incômodo' → Language = pt-BR
# Updating row 80: 'Arsène Lupin contra Herlock Sholmes' → Language = pt-BR
# Updating row 81: 'Arsène Lupin o ladrão de casaca' → Language = pt-BR
# Updating row 82: 'Duna' → Language = pt
# Updating row 83: 'Encontro com Rama' → Language = pt-BR
# Updating row 84: 'Eu receberia as piores noticias dos seus lindos lábios' → Language = pt-BR
# Updating row 85: 'Eu robo' → Language = pt-BR
# Updating row 86: 'Fahrenheit 451' → Language = en
# Updating row 87: 'Messias de Duna' → Language = pt-BR
# Updating row 88: 'O chamado de Cthulhu e outros contos' → Language = pt-BR
# Updating row 89: 'Uma mulher no escuro' → Language = pt-BR
# Updating row 90: 'Admirável mundo novo' → Language = pt-BR
# Updating row 91: 'Deuses Exteriores e Deuses Anciãos' → Language = Unknown
# Updating row 92: 'Livro Fenomenal' → Language = Unknown
# Updating row 93: 'O Homem invisível' → Language = pt-BR
# Updating row 94: 'Os Grandes Antigos' → Language = Unknown
# Updating row 95: 'Primeiro como tragédia, depois como farsa' → Language = pt-BR
# Updating row 96: 'Serviçais e raças independentes' → Language = Unknown
# Updating row 97: 'Murder at Holly House' → Language = en
# Updating row 98: 'As esganadas' → Language = pt-BR
# Updating row 99: 'Crônicas 1' → Language = pt-BR
# Updating row 100: 'Depois daquela viagem' → Language = pt-BR
# Updating row 101: 'Extremamente alto & Incrivelmente perto' → Language = Unknown
# Updating row 102: 'Melhores Poemas Mario Quintana' → Language = pt
# Updating row 103: 'Nietzsche para estressados' → Language = pt-BR
# Updating row 104: 'O lobo das planices' → Language = Unknown
# Updating row 105: 'O retrato de Dorian Gray' → Language = pt-BR
# Updating row 106: 'O Senhor da Chuva' → Language = pt-BR
# Updating row 107: 'O Senhor do Arco' → Language = pt-BR
# Updating row 108: 'Quadribol através dos séculos' → Language = pt-BR
# Updating row 109: 'Sherlock Holme - O Cão de Baskervilles' → Language = pt-BR
# Updating row 110: 'Sherlock Holmes - O Vale do Terror' → Language = pt-BR
# Updating row 111: 'A morte e a morte de Quincas Berro Dágua' → Language = pt-BR

# %%
info = "publishedDate"

insert_info_in_sheet(sheet, info)
# Out:
# Updating row 2: 'O Cortiço' → Publisheddate = 2024-07-20
# Updating row 3: 'Harry Potter e a Pedra Filosofal' → Publisheddate = 2023-01-17
# Updating row 4: 'Harry Potter e a Câmara Secreta' → Publisheddate = 2015-12-08
# Updating row 5: 'Harry Potter e o Cálice de Fogo' → Publisheddate = 2002
# Updating row 6: 'Harry Potter e o Prizioneiro de Azkaban' → Publisheddate = 2002
# Updating row 7: 'Meu Pé de Laranja Lima' → Publisheddate = 2013-03-26
# Updating row 8: 'Amor não tem cor' → Publisheddate = 2002
# Updating row 9: 'Auto da Compadecida' → Publisheddate = 2024-11-21
# Updating row 10: 'Memórias póstumas de Brás Cubas' → Publisheddate = 2024-06-28
# Updating row 11: 'O Fantasma de Canterville - Uma novela e três contos' → Publisheddate = 2021-07-30
# Updating row 12: 'O Grande Mentecapto' → Publisheddate = 2020-06-29
# Updating row 13: 'Ponciá Vicêncio' → Publisheddate = 2020-08-10
# Updating row 14: 'Senhora' → Publisheddate = 2010
# Updating row 15: '26 Poetas Hoje' → Publisheddate = 2021-02-24
# Updating row 16: 'Maira' → Publisheddate = 1984
# Updating row 17: 'O recado do Morro' → Publisheddate = 2013-09-18
# Updating row 18: 'Prosas seguidas de odes mínimas' → Publisheddate = 1992
# Updating row 19: 'A vida, o universo e tudo mais' → Publisheddate = 2010-11-09
# Updating row 20: 'Até mais, e obrigado pelos peixes!' → Publisheddate = 2010-11-09
# Updating row 21: 'O Guia do Mochilero das Galáxias' → Publisheddate = 2010-11-09
# Updating row 22: 'O Restaurante no fim do Universo' → Publisheddate = 2022-10-10
# Updating row 23: 'Antes do Baile Verde' → Publisheddate = 2009-04-23
# Updating row 24: 'Bastardos Inglórios' → Publisheddate = Unknown
# Updating row 25: 'Cobra Norato' → Publisheddate = 2016-11-25
# Updating row 26: 'Cônica da casa assassinada' → Publisheddate = 1991
# Updating row 27: 'Laços de Família' → Publisheddate = 2020-06-19
# Updating row 28: 'Os da minha rua' → Publisheddate = 2010-09-30
# Updating row 29: 'Sermões Escolhidos' → Publisheddate = 2023-12-22
# Updating row 30: 'Uma vida em Segredo' → Publisheddate = 1983
# Updating row 31: 'A arte da Guerra' → Publisheddate = 2014-02-05
# Updating row 32: 'Através do Espelo e o que Alice encontrou por lá' → Publisheddate = 2024-12-01
# Updating row 33: 'Aventuras de Alice no país das maravilhas' → Publisheddate = 2016
# Updating row 34: 'O Iluminado' → Publisheddate = 2017-08-22
# Updating row 35: 'A Fúria dos Reis' → Publisheddate = 2019-04-23
# Updating row 36: 'A Guerra dos Tronos' → Publisheddate = 2019-03-25
# Updating row 37: 'A Tormenta das Espadas' → Publisheddate = 2019-04-23
# Updating row 38: 'O Festim dos Corvos' → Publisheddate = 2019-11-11
# Updating row 39: 'A Dance with Dragons' → Publisheddate = 2011
# Updating row 40: 'A menina que roubava Livros' → Publisheddate = 2012-11-13
# Updating row 41: 'A Dança dos Dragões' → Publisheddate = 2020-03-25
# Updating row 42: 'Contos Inacabados' → Publisheddate = 2024-07-15
# Updating row 43: 'Deuses Americanos' → Publisheddate = 2019
# Updating row 44: 'Mitologia Nórdica' → Publisheddate = 2017-03-13
# Updating row 45: 'Morte no Nilo' → Publisheddate = 2015-04-17
# Updating row 46: 'O Assassinato No Expresso Oriente' → Publisheddate = 2014-04-15
# Updating row 47: 'O Caso de Charles Dexter Ward' → Publisheddate = 2025-03-22
# Updating row 48: 'O oceano no fim do caminho' → Publisheddate = 2024-02-05
# Updating row 49: 'Os meninos da Rua Paulo' → Publisheddate = 2023-05-02
# Updating row 50: 'Um corpo na Biblioteca' → Publisheddate = 2015-01-15
# Updating row 51: 'A História da Mitologia para quem tem pressa' → Publisheddate = 2015-12-01
# Updating row 52: 'A Náusea' → Publisheddate = 2006
# Updating row 53: 'Astrofísica para Apressados' → Publisheddate = 2017-08-01
# Updating row 54: 'Buracos Negros' → Publisheddate = 2017-01-26
# Updating row 55: 'Cosmos' → Publisheddate = 2011-07-06
# Updating row 56: 'O gigante enterrado' → Publisheddate = 2015-06-12
# Updating row 57: 'O inverno dos escritores mortos' → Publisheddate = Unknown
# Updating row 58: 'Tropas Estrelares' → Publisheddate = 2015-10-28
# Updating row 59: 'Um Estranho numa terra estranha' → Publisheddate = 2017-03-24
# Updating row 60: 'Uma Breve história do tempo' → Publisheddate = 2015-01-13
# Updating row 61: 'A Trilogia Dupin' → Publisheddate = 2020-05-06
# Updating row 62: 'Harry Potter e a Ordem da Fênix' → Publisheddate = 2003
# Updating row 63: 'Harry Potter e as Relíquias da Morte' → Publisheddate = 2008-02-21
# Updating row 64: 'Harry Potter e o Enigma do Príncipe' → Publisheddate = 2015-12-08
# Updating row 65: 'Não me abandone jamais' → Publisheddate = 2005-10-04
# Updating row 66: 'Neuromancer' → Publisheddate = 2015-09-16
# Updating row 67: 'O Livro do Cemitério' → Publisheddate = 2018-06-04
# Updating row 68: 'O universo numa casca de noz' → Publisheddate = 2016-02-01
# Updating row 69: 'As mais belas lendas da Idade Média' → Publisheddate = 2001
# Updating row 70: 'Barba ensopada de sangue' → Publisheddate = 2012-11-05
# Updating row 71: 'Coraline' → Publisheddate = 2020-06-19
# Updating row 72: 'Flores para Algernon' → Publisheddate = 2018-07-10
# Updating row 73: 'Jackob, o mentiroso' → Publisheddate = 2022
# Updating row 74: 'Labirinto do Fauno' → Publisheddate = 2019-07-10
# Updating row 75: 'Metrópolis' → Publisheddate = 2021-03-23
# Updating row 76: 'O Demônio na Cidade Branca' → Publisheddate = 2016-07-12
# Updating row 77: 'O Perfume' → Publisheddate = 2022-10-03
# Updating row 78: 'Os Filhos de Húrin' → Publisheddate = 2020-02-17
# Updating row 79: 'Um amor incômodo' → Publisheddate = 2017-03-20
# Updating row 80: 'Arsène Lupin contra Herlock Sholmes' → Publisheddate = 2021-03-01
# Updating row 81: 'Arsène Lupin o ladrão de casaca' → Publisheddate = 2021-06-29
# Updating row 82: 'Duna' → Publisheddate = 2015-09-16
# Updating row 83: 'Encontro com Rama' → Publisheddate = 2015-09-16
# Updating row 84: 'Eu receberia as piores noticias dos seus lindos lábios' → Publisheddate = 2005-10-31
# Updating row 85: 'Eu robo' → Publisheddate = 2015-09-16
# Updating row 86: 'Fahrenheit 451' → Publisheddate = 2003-09-23
# Updating row 87: 'Messias de Duna' → Publisheddate = 2017-06-09
# Updating row 88: 'O chamado de Cthulhu e outros contos' → Publisheddate = 2020-06-10
# Updating row 89: 'Uma mulher no escuro' → Publisheddate = 2019-05-31
# Updating row 90: 'Admirável mundo novo' → Publisheddate = 2014-03-06
# Updating row 91: 'Deuses Exteriores e Deuses Anciãos' → Publisheddate = Unknown
# Updating row 92: 'Livro Fenomenal' → Publisheddate = Unknown
# Updating row 93: 'O Homem invisível' → Publisheddate = 2017-04-04
# Updating row 94: 'Os Grandes Antigos' → Publisheddate = Unknown
# Updating row 95: 'Primeiro como tragédia, depois como farsa' → Publisheddate = 2015-10-26
# Updating row 96: 'Serviçais e raças independentes' → Publisheddate = Unknown
# Updating row 97: 'Murder at Holly House' → Publisheddate = 2023-11-09
# Updating row 98: 'As esganadas' → Publisheddate = 2011-10-14
# Updating row 99: 'Crônicas 1' → Publisheddate = 1982
# Updating row 100: 'Depois daquela viagem' → Publisheddate = 2013
# Updating row 101: 'Extremamente alto & Incrivelmente perto' → Publisheddate = Unknown
# Updating row 102: 'Melhores Poemas Mario Quintana' → Publisheddate = 2015-09-04
# Updating row 103: 'Nietzsche para estressados' → Publisheddate = 2011-10-17
# Updating row 104: 'O lobo das planices' → Publisheddate = Unknown
# Updating row 105: 'O retrato de Dorian Gray' → Publisheddate = 2024-10-24
# Updating row 106: 'O Senhor da Chuva' → Publisheddate = Unknown
# Updating row 107: 'O Senhor do Arco' → Publisheddate = 2022-08-09
# Updating row 108: 'Quadribol através dos séculos' → Publisheddate = 2016-05-09
# Updating row 109: 'Sherlock Holme - O Cão de Baskervilles' → Publisheddate = 2021-03-18
# Updating row 110: 'Sherlock Holmes - O Vale do Terror' → Publisheddate = 2021-03-18
# Updating row 111: 'A morte e a morte de Quincas Berro Dágua' → Publisheddate = 2008-03-10

# %%
save_sheet_as_sql(sheet, table_name="books", output_file="MyLibrary.sql")
# Out:
# SQL export complete: MyLibrary.sql

# %%
save_sheet_as_json(sheet, output_filename= "MyLibrary.json")
# Out:
# Sheet '<Spreadsheet 'Biblioteca' id:19JV7gS3Iy_MTOluozSech3iFmkxRF11oCVYLhp1ziN0>' saved as 'MyLibrary.json'

# %% [markdown]
# ___
